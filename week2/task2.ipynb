# %%
import pandas as pd
data = {
    "Model": ["Linear Regression", "Decision Tree", "Random Forest", "KNN", "Neural Network"],
    "Accuracy": [78, 82, 89, 80, 94],
    "Training_Time": [2, 5, 10, 3, 15],
    "Dataset_Size": [1000, 1500, 2000, 1200, 2500]
}

df = pd.DataFrame(data)

print(df)
# Out:
#                Model  Accuracy  Training_Time  Dataset_Size
# 0  Linear Regression        78              2          1000
# 1      Decision Tree        82              5          1500
# 2      Random Forest        89             10          2000
# 3                KNN        80              3          1200
# 4     Neural Network        94             15          2500

# %%
df.to_csv("ai_model_performance.csv", index=False)

print("Dataset saved successfully.")
# Out:
# Dataset saved successfully.

# %%
df = pd.read_csv("ai_model_performance.csv")

print(df)
# Out:
#                Model  Accuracy  Training_Time  Dataset_Size
# 0  Linear Regression        78              2          1000
# 1      Decision Tree        82              5          1500
# 2      Random Forest        89             10          2000
# 3                KNN        80              3          1200
# 4     Neural Network        94             15          2500

# %%
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#                Model  Accuracy  Training_Time  Dataset_Size
# 0  Linear Regression        78              2          1000
# 1      Decision Tree        82              5          1500
# 2      Random Forest        89             10          2000
# 3                KNN        80              3          1200
# 4     Neural Network        94             15          2500

# %%
print("Last 5 rows:")
print(df.tail())
# Out:
# Last 5 rows:
#                Model  Accuracy  Training_Time  Dataset_Size
# 0  Linear Regression        78              2          1000
# 1      Decision Tree        82              5          1500
# 2      Random Forest        89             10          2000
# 3                KNN        80              3          1200
# 4     Neural Network        94             15          2500

# %%
print("Number of rows and columns:", df.shape)
# Out:
# Number of rows and columns: (5, 4)

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 5
# Number of columns: 4

# %%
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# Model              str
# Accuracy         int64
# Training_Time    int64
# Dataset_Size     int64
# dtype: object

# %%
print("Statistical Information:")
print(df.describe())
# Out:
# Statistical Information:
#        Accuracy  Training_Time  Dataset_Size
# count   5.00000        5.00000      5.000000
# mean   84.60000        7.00000   1640.000000
# std     6.69328        5.43139    610.737259
# min    78.00000        2.00000   1000.000000
# 25%    80.00000        3.00000   1200.000000
# 50%    82.00000        5.00000   1500.000000
# 75%    89.00000       10.00000   2000.000000
# max    94.00000       15.00000   2500.000000

# %%
print(df["Accuracy"])
print(df[["Model", "Accuracy"]])
# Out:
# 0    78
# 1    82
# 2    89
# 3    80
# 4    94
# Name: Accuracy, dtype: int64
#                Model  Accuracy
# 0  Linear Regression        78
# 1      Decision Tree        82
# 2      Random Forest        89
# 3                KNN        80
# 4     Neural Network        94

# %%
high_accuracy = df[df["Accuracy"] > 85]

print("Models with accuracy greater than 85%:")
print(high_accuracy)
# Out:
# Models with accuracy greater than 85%:
#             Model  Accuracy  Training_Time  Dataset_Size
# 2   Random Forest        89             10          2000
# 4  Neural Network        94             15          2500
